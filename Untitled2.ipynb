# %%
import json
import requests

# %%
def translate_data(data: list[str], lang):
    headers = {
        "accept": "*/*",
        "accept-language": "en-GB,en-US;q=0.9,en;q=0.8",
        "content-type": "application/json+protobuf",
        "priority": "u=1, i",
        "sec-ch-ua": "\"Not)A;Brand\";v=\"99\", \"Google Chrome\";v=\"127\", \"Chromium\";v=\"127\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "cross-site",
        "x-client-data": "CIu2yQEIprbJAQipncoBCKeXywEIk6HLAQia/swBCOmYzQEIhaDNAQ==",
        "x-goog-api-key": "AIzaSyATBXajvzQLTDHEQbcpq0Ihe0vWDHmO520",
    }

    url = "https://translate-pa.googleapis.com/v1/translateHtml"
    body = [[data, lang, "en"], "te_lib"]
    response = requests.post(url, headers=headers, json=body)
    if response.status_code == 200:
        try:
            return json.loads(response.text)[0]
        except Exception as ex:
            print(f'Error at google translate : {ex}\n{response.text}')
    else:
        print(f'Error at translation, Status code : {response.status_code}')
    return data
def remove_values(value):
    catalog = value['Catalog']
    remove = ['solo®', 'by', 'By', 'BY', 'Solo', 'Al-ko', 'AL-KO', 'AL-KO']
    for r in remove:
        catalog = catalog.replace(r, '')
    value['Catalog'] = ' '.join([item for item in str(catalog).rstrip('Al').rstrip('B').strip().split(' ') if item])
    return value

# %%
with open('ApiData.json', 'r') as api_data_file:
    api_data =json.loads( api_data_file.read())

# %%
fi_api_data = [data['SGL'] for data in api_data if data['CountryCode'] == 'fi']

# %%
with open('Scraped Data.json', 'r') as scraped_data_file:
    scraped_data =json.loads( scraped_data_file.read())

# %%
for data in scraped_data:
    catalog = data['Catalog']
    remove_values(data)
    parts = data['Parts']
    translated_descriptions = translate_data([part['Desctiption'] for part in parts], 'de')
    for part, translated_description in zip(data['Parts'], translated_descriptions):
        part['Desctiption'] = translated_description

# %%
with open('Translated Data.json', 'w') as scraped_data_file:
    scraped_data_file.write(json.dumps(scraped_data, indent=4))

# %%
with open('Translated Data.json', 'r') as scraped_data_file:
    scraped_data =json.loads( scraped_data_file.read())

# %%
len(scraped_data)
# Out:
# 602

# %%
with open(r'D:\Workspace\Projects\AlKoScraper\Translated Data.json', 'r') as json_file:
    data = [{"Img Url": item["Img Url"], 'Img Filename': item['Img Filename']} for item in json.load(json_file)]

# %%
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "Img Url": "https://alko-garden.fi/out/media/exploded_views/2020/4/2020-04-127417-10.gif",
#         "Img Filename": "SGL0000075703-Tractor T15-93.7 Hd-a Comfort Solo By.jpg"
#     },
#     {
#         "Img Url": "https://alko-garden.fi/out/media/exploded_views/2023/1/2023-01-127690-10.gif",
#         "Img Filename": "SGL0000002013-Tractor T16-93.3 Hd V2 Comfort Solo By.jpg"
#     },
#     {
#         "Img Url": "https://alko-garden.fi/out/media/exploded_views/2020/4/2020-04-127369-10.gif",
#         "Img Filename": "SGL0000002014-Tractor T16-95.6 Hd V2 Solo By Al-ko.jpg"
#     },
#     {
#         "Img Url": "https://alko-garden.fi/out/media/exploded_views/2022/3/2022-03-127653-10.gif",
#         "Img Filename": "SGL0000002015-Tractor solo\u00ae by AL-KO T 24-125.2 HD V2 SD.jpg"
#     },
#     {
#         "Img Url": "https://alko-garden.fi/out/media/exploded_views/2020/1/2020-01-127575-10.gif",
# ...
