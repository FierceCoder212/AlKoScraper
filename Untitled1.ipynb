# %%
import json
import re
from urllib.parse import urljoin

import requests
from bs4 import BeautifulSoup

# %%
def translate_data(data: list[str], lang):
    headers = {
        "accept": "*/*",
        "accept-language": "en-GB,en-US;q=0.9,en;q=0.8",
        "content-type": "application/json+protobuf",
        "priority": "u=1, i",
        "sec-ch-ua": "\"Not)A;Brand\";v=\"99\", \"Google Chrome\";v=\"127\", \"Chromium\";v=\"127\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "cross-site",
        "x-client-data": "CIu2yQEIprbJAQipncoBCKeXywEIk6HLAQia/swBCOmYzQEIhaDNAQ==",
        "x-goog-api-key": "AIzaSyATBXajvzQLTDHEQbcpq0Ihe0vWDHmO520",
    }

    url = "https://translate-pa.googleapis.com/v1/translateHtml"
    body = [[data, lang, "en"], "te_lib"]
    response = requests.post(url, headers=headers, json=body)
    if response.status_code == 200:
        try:
            return json.loads(response.text)[0]
        except Exception as ex:
            print(f'Error at google translate : {ex}\n{response.text}')
    else:
        print(f'Error at translation, Status code : {response.status_code}')
    return data


def get_spare_parts(soup: BeautifulSoup):
    spare_parts = soup.select(
        'div[class="imagemap-content accordion"] input.search-for-spareparts+div.row div.table-rows')
    spare_part_obj = []
    for spare_part in spare_parts:
        items = [item for item in spare_part.text.split('\n') if item]
        item_number = items[0]
        description = items[1]
        spare_part_obj.append({
            'Item Number': item_number,
            'Desctiption': description
        })
    return spare_part_obj


def _sanitize_filename(filename: str) -> str:
    invalid_chars = r'[<>:"/\\|?*\']'
    sanitized_filename = re.sub(invalid_chars, "_", filename)
    sanitized_filename = sanitized_filename.strip()
    sanitized_filename = sanitized_filename[:255]
    return sanitized_filename


def scrape_data(data):
    url = data['URL']
    catalog = data['Catalog']
    sgl_code = data['SGL']
    language = data['lang']
    try:
        response = requests.get(url)
        print(response.status_code)
        if response.status_code == 200:
            html = response.json()['html']
            soup = BeautifulSoup(html, 'html.parser')
            img_url = urljoin(url, soup.select_one('div.explodedViewsContainer img').get('src'))
            parts = get_spare_parts(soup)
            translated_parts = translate_data([part['Desctiption'] for part in parts], language)
            for part, translated_description in zip(parts, translated_parts):
                part['Description'] = translated_description
            img_filename = _sanitize_filename(f'{sgl_code}-{catalog}.jpg')
            return {
                'SGL': sgl_code,
                'Catalog': catalog,
                'Parts': parts,
                'Img Url': img_url,
                'Img Filename': img_filename
            }
        else:
            print('Response Error')
    except Exception as e:
        print(f'Exception at {sgl_code}')
    return None

# %%
with open(f"All Data.json", 'r') as json_file:
    all_data = json.load(json_file)

# %%
objs = []
for index, d in enumerate(all_data):
    print(f'On {index} out of {len(all_data)} : {d['SGL']}')
    val = scrape_data(d)
    if val:
        objs.append(val)
# Out:
# On 0 out of 36 : SGL0000075639
# 200
# On 1 out of 36 : SGL0000075640
# 200
# Exception at SGL0000075640
# On 2 out of 36 : SGL0000075703
# 200
# On 3 out of 36 : SGL0000002013
# 200
# On 4 out of 36 : SGL0000002014
# 200
# On 5 out of 36 : SGL0000002015
# 200
# On 6 out of 36 : SGL0000002016
# 200
# On 7 out of 36 : SGL0000002017
# 200
# On 8 out of 36 : SGL0000002018
# 200
# On 9 out of 36 : SGL0000002019
# 200
# On 10 out of 36 : SGL0000002020
# Exception at SGL0000002020
# On 11 out of 36 : SGL0000002021
# Exception at SGL0000002021
# On 12 out of 36 : SGL0000002022
# 200
# On 13 out of 36 : SGL0000002023
# 200
# On 14 out of 36 : SGL0000002024
# 200
# On 15 out of 36 : SGL0000002025
# 200
# On 16 out of 36 : SGL0000002026
# 200
# On 17 out of 36 : SGL0000002027
# 200
# On 18 out of 36 : SGL0000002029
# 200
# On 19 out of 36 : SGL0000002030
# 200
# On 20 out of 36 : SGL0000002031
# 200
# On 21 out of 36 : SGL0000002032
# 200
# On 22 out of 36 : SGL0000002040
# 200
# Exception at SGL0000002040
# On 23 out of 36 : SGL0000002043
# 200
# On 24 out of 36 : SGL0000002044
# 200
# On 25 out of 36 : SGL0000002045
# 200
# On 26 out of 36 : SGL0000015815
# 200
# On 27 out of 36 : SGL0000015816
# 200
# On 28 out of 36 : SGL0000015817
# 200
# On 29 out of 36 : SGL0000015818
# 200
# On 30 out of 36 : SGL0000015819
# 200
# On 31 out of 36 : SGL0000015820
# 200
# On 32 out of 36 : SGL0000015821
# 200
# On 33 out of 36 : SGL0000015822
# 200
# On 34 out of 36 : SGL0000002012
# 200
# On 35 out of 36 : SGL0000015814
# 200

# %%
with open(f"Scraped Data.json", 'w') as json_file:
    json_file.write(json.dumps(objs, indent=4))

# %%
objs
# Out:
# [{'SGL': 'SGL0000075639',
#   'Catalog': 'Gasoline lawn tractor T 18-111.4 HDS-A V2',
#   'Parts': [{'Item Number': '51400402',
#     'Desctiption': 'Mittelkonsole Vorne R3000',
#     'Description': 'Center console front R3000'},
#    {'Item Number': '457760',
#     'Desctiption': '9039-490-0994-a Gew.forms. Din7500-m6x16',
#     'Description': '9039-490-0994-a Weight Forms. Din7500-m6x16'},
#    {'Item Number': '49300601',
#     'Desctiption': 'Trittplatte Rechts R9005',
#     'Description': 'Tread plate right R9005'},
#    {'Item Number': '49300701',
#     'Desctiption': 'Trittplatte Links R9005',
#     'Description': 'Tread plate left R9005'},
#    {'Item Number': '49308001',
#     'Desctiption': 'Konsole Motorhaube E R9005',
#     'Description': 'Console bonnet E R9005'},
#    {'Item Number': '746005',
#     'Desctiption': 'Shr 6x 40 7985- 4.8-tx30 A3b',
#     'Description': 'Shr6x40 7985-4.8-tx30 A3b'},
#    {'Item Number': '705657',
#     'Desctiption': 'Mu 6kt  6  En1663-  8  A2k',
#     'Description': 'Mu 6kt 6 En1663- 8 A2k'},
#    {'Item Number': '514166',
#     'Desctiption': 'Sitz Seat 1',
#     'Description': 'Seat Seat 1'},
#    {'Item Number': '518482',
#     'Desctiption': 'Shr Pt-k 50x18 1451 A2k',
#     'Description': 'Shr Pt-k 50x18 1451 A2k'},
#    {'Item Number': '493162',
#     'Desctiption': 'Bedienkonsole Ta Y-silber  Choker E 2zy',
#     'Description': 'Control console Ta Y-silver Choker E 2zy'},
#    {'Item Number': '464307',
#     'Desctiption': 'Lenkrad Kpl',
#     'Description': 'Steering wheel cpl'},
#    {'Item Number': '46111802',
#     'Desctiption': 'Abdeckkappe Für Lenkrad R3000',
#     'Description': 'Cover cap for steering wheel R3000'},
#    {'Item Number': '701508',
#     'Desctiption': 'Shr10x 70 Din933- 8.8 Vz',
#     'Description': 'Shr10x 70 Din933- 8.8 Vz'},
#    {'Item Number': '705284',
#     'Desctiption': 'Fed Tel 28  X10,2x1,5  2093',
#     'Description': 'Fed Tel 28 X10,2x1,5 2093'},
#    {'Item Number': '51524630',
#     'Desctiption': 'Scheibe 30/10,5 X 5 Verz',
#     'Description': 'Disc 30/10.5 X 5 galvanized'},
#    {'Item Number': '52193702',
#     'Desctiption': 'Mittelkonsole Hinten Nacharbeit R3000',
#     'Description': 'Center console rear rework R3000'},
#    {'Item Number': '51414801',
#     'Desctiption': 'Abdeckung Höhenverstellung R9005',
#     'Description': 'Cover height adjustment R9005'},
#    {'Item Number': '514544',
#     'Desctiption': 'Shr Pt-kb 60x30 Wn1451 A2k',
#     'Description': 'Shr Pt-kb 60x30 Wn1451 A2k'},
#    {'Item Number': '473781',
#     'Desctiption': 'Mähdeckschalter Al-ko Tamp',
#     'Description': 'Mower deck switch Al-ko Tamp'},
#    {'Item Number': '46177401',
#     'Desctiption': 'Abdeckung Schaltkulisse Fussc R9005',
#     'Description': 'Cover gearshift gate foot R9005'},
#    {'Item Number': '468878',
#     'Desctiption': 'Shr Pt-kb 50x12 Wn1451 Znni8f',
#     'Description': 'Shr Pt-kb 50x12 Wn1451 Znni8f'},
#    {'Item Number': '521724',
#     'Desctiption': 'Abdeckung Für Schalter Box U Mähd',
#     'Description': 'Cover For Switch Box U Mower'},
#    {'Item Number': '52113801',
#     'Desctiption': 'Abdeckkappe Mittelkonsole R9005',
#     'Description': 'Cover cap center console R9005'},
#    {'Item Number': '5218650210',
#     'Desctiption': 'Heckverkleidung Sa Nacharbeit R3000',
#     'Description': 'Rear panel Sa rework R3000'},
#    {'Item Number': '521676',
#     'Desctiption': 'Blechmutter 4,8 Mm  Nr 013832',
#     'Description': 'Sheet metal nut 4.8 mm No. 013832'},
#    {'Item Number': '703005',
#     'Desctiption': 'Shb   6,4 9021-st Znni8f',
#     'Description': 'Shb 6,4 9021-st Znni8f'},
#    {'Item Number': '706562',
#     'Desctiption': 'Shr St4,8x25  -c-torx 7981 Znni8f',
#     'Description': 'Shr St4.8x25 -c-torx 7981 Znni8f'},
#    {'Item Number': '468569',
#     'Desctiption': '9102-090-3781-a L Tx 4,8x16 F  Znni8f',
#     'Description': '9102-090-3781-a L Tx 4.8x16 F Znni8f'},
#    {'Item Number': '49374101',
#     'Desctiption': "'Oberteil Motorhaube Comfort Neu R9005'",
#     'Description': '&#39;Upper part bonnet Comfort New R9005&#39;'},
#    {'Item Number': '49374402',
#     'Desctiption': "'Blende Motorhaube Li Comfort Neu R3000'",
#     'Description': '&#39;Cover bonnet Li Comfort New R3000&#39;'},
#    {'Item Number': '49374201',
#     'Desctiption': "'Seitenteil Motorhaube Li Comf Neu R9005'",
#     'Description': '&#39;Side panel bonnet Li Comf New R9005&#39;'},
#    {'Item Number': '493758',
#     'Desctiption': 'Schriftzug Motorhaube Sba Seitl',
#     'Description': 'Lettering bonnet Sba side'},
#    {'Item Number': '49374301',
#     'Desctiption': "'Seitenteil Motorhaube Re Comf Neu R9005'",
#     'Description': '&#39;Side panel bonnet Re Comf New R9005&#39;'},
#    {'Item Number': '49374502',
#     'Desctiption': "'Blende Motorhaube Re Comfort Neu R3000'",
#     'Description': '&#39;Cover Bonnet Re Comfort New R3000&#39;'},
#    {'Item Number': '493789',
#     'Desctiption': "'3d Schriftzug Motorhaube Sba Re'",
#     'Description': '&#39;3d lettering bonnet Sba Re&#39;'},
#    {'Item Number': '49374601',
#     'Desctiption': "'Frontteil Motorhaube Comfort Neu R9005'",
#     'Description': '&#39;Front part bonnet Comfort New R9005&#39;'},
#    {'Item Number': '493747',
#     'Desctiption': 'Lichtscheibe Motorhaube Li',
#     'Description': 'Lens hood left'},
#    {'Item Number': '493748',
#     'Desctiption': 'Lichtscheibe Motorhaube Re',
#     'Description': 'Lens bonnet right'},
#    {'Item Number': '493749',
#     'Desctiption': 'Reflektor Motorhaube Li',
#     'Description': 'Reflector bonnet left'},
#    {'Item Number': '493750',
#     'Desctiption': 'Reflektor Motorhaube Re',
#     'Description': 'Reflector bonnet right'},
#    {'Item Number': '49375102',
#     'Desctiption': "'Smart Button Motorhaube Comf Neu R3000'",
#     'Description': '&#39;Smart Button Bonnet Comf New R3000&#39;'},
#    {'Item Number': '493757',
#     'Desctiption': 'Schriftzug Motorhaube Sba Vo',
#     'Description': 'Lettering bonnet Sba Vo'},
#    {'Item Number': '473723',
#     'Desctiption': '9286-003-1000-a Blechmutter M6',
#     'Description': '9286-003-1000-a sheet metal nut M6'},
#    {'Item Number': '471472',
#     'Desctiption': 'Shr Skt 6x 12 Sperrz. 8.8 Znni5fnt2',
#     'Description': 'Shr Skt 6x 12 locking pins 8.8 Znni5fnt2'},
#    {'Item Number': '526611',
#     'Desctiption': 'Pt-k Torx 60x14 Wn1451 A2k',
#     'Description': 'Pt-k Torx 60x14 Wn1451 A2k'},
#    {'Item Number': '51441930',
#     'Desctiption': 'Federstahldraht Verz',
#     'Description': 'Spring steel wire galvanized'},
#    {'Item Number': '544515',
#     'Desctiption': 'Schlauchklemme 14,5  B&s  93053',
#     'Description': 'Hose clamp 14.5 B&amp;s 93053'},
#    {'Item Number': '51437910',
#     'Desctiption': 'Benzinschlauch Zuschnitt',
#     'Description': 'Fuel hose cut'},
#    {'Item Number': '49300101',
#     'Desctiption': 'Rahmen 93-103 Geschw E R9005',
#     'Description': 'Frame 93-103 Speed \u200b\u200bR9005'},
#    {'Item Number': '704537',
#     'Desctiption': 'Mu 6kt  8   Din985- 8 A3b',
#     'Description': 'Mu 6kt 8 Din985- 8 A3b'},
#    {'Item Number': '468768',
#     'Desctiption': '0000-350-1000-a Benzinhahn B&s',
#     'Description': '0000-350-1000-a fuel tap B&amp;s'},
#    {'Item Number': '700148',
#     'Desctiption': 'Shb   6,4 9021-st  Vz',
#     'Description': 'Shb 6,4 9021-st Vz'},
#    {'Item Number': '700561',
#     'Desctiption': 'Shr10x 25 Din933- 8.8 Vz',
#     'Description': 'Shr10x 25 Din933- 8.8 Vz'},
#    {'Item Number': '705360',
#     'Desctiption': 'Shr 10x1,0 X 35 Din961-10.9 A3b',
#     'Description': 'Shr 10x1.0X35 Din961-10.9 A3b'},
#    {'Item Number': '47312030',
#     'Desctiption': '6165-703-4800-a Zahnsegment Av Verz',
#     'Description': '6165-703-4800-a Tooth segment Av Verz'},
#    {'Item Number': '473115',
#     'Desctiption': '6165-763-3000-a Lagerbuchse Lenks Av',
#     'Description': '6165-763-3000-a bearing bush steering Av'},
#    {'Item Number': '703813',
#     'Desctiption': 'Mu 6kt 10      Din985-10 A3b',
#     'Description': 'Mu 6kt 10 Din985-10 A3b'},
#    {'Item Number': '47317310',
#     'Desctiption': '6165-763-3200-a Bundsch  Lenks Härten',
#     'Description': '6165-763-3200-a Bundsch Lenks Hardening'},
#    {'Item Number': '706018',
#     'Desctiption': 'Mu 6kt 10x1    Din985-10 A2k',
#     'Description': 'Mu 6kt 10x1 Din985-10 A2k'},
#    {'Item Number': '464932',
#     'Desctiption': 'Kugelzapfen 16/gew-l.20mm Verstärkt',
#     'Description': 'Ball stud 16/gew-l.20mm reinforced'},
#    {'Item Number': '47311630',
#     'Desctiption': '6165-703-1700-a Schubstange Le Av Verz',
#     'Description': '6165-703-1700-a Push rod Le Av Verz'},
#    {'Item Number': '704534',
#     'Desctiption': 'Mu 6kt  10   Din934- 8 A3b',
#     'Description': 'Mu 6kt 10 Din934- 8 A3b'},
#    {'Item Number': '701985',
#     'Desctiption': 'Shr 8x 55 Din931- 8.8 Vz',
#     'Description': 'Shr 8x 55 Din931- 8.8 Vz'},
#    {'Item Number': '701083',
#     'Desctiption': 'Shb  8,4 Din7349 Vz',
#     'Description': 'Shb 8,4 Din7349 Vz'},
#    {'Item Number': '46110830',
#     'Desctiption': 'Lenkhebel 2 Teilig Oben  Verz',
#     'Description': 'Steering lever 2 parts top galvanized'},
#    {'Item Number': '46110730',
#     'Desctiption': 'Lenkhebel 2 Teilig Unten Verz',
#     'Description': 'Steering lever 2 parts bottom galvanized'},
#    {'Item Number': '692795',
#     'Desctiption': 'Mu Sich- Biw M 8 A2k- 8 Mittelgesichert',
#     'Description': 'Mu Sich- Biw M 8 A2k- 8 Medium secured'},
#    {'Item Number': '523134',
#     'Desctiption': 'Sfs-tapt M6x12 2021 A2k',
#     'Description': 'Sfs tap M6x12 2021 A2k'},
#    {'Item Number': '514704',
#     'Desctiption': 'Sicherungsbügel Für Winkelgelenk',
#     'Description': 'Safety bracket for angle joint'},
#    {'Item Number': '514706',
#     'Desctiption': 'Kugelpfanne M.sich-loch',
#     'Description': 'Ball socket with hole'},
#    {'Item Number': '704532',
#     'Desctiption': 'Mu  6        Din934- 8 A3b',
#     'Description': 'Mu 6 Din934-8 A3b'},
#    {'Item Number': '700934',
#     'Desctiption': 'Shr 6x 55 Din933- 8.8 Vz',
#     'Description': 'Shr 6x 55 Din933- 8.8 Vz'},
#    {'Item Number': '46876530',
#     'Desctiption': '6170-021-8200-a Ölablassschraube Verz',
#     'Description': '6170-021-8200-a Oil drain plug galvanized'},
#    {'Item Number': '468766',
#     'Desctiption': '6170-028-1100-a Verschlussdeckel Öl B&s',
#     'Description': '6170-028-1100-a Oil cap B&amp;s'},
#    {'Item Number': '494196',
#     'Desctiption': 'P-engine Pro 600 V2 Lc2p73f R9005 Eu5',
#     'Description': 'P-engine Pro 600 V2 Lc2p73f R9005 Eu5'},
#    {'Item Number': '468767',
#     'Desctiption': '6170-029-0500-a Dichtung Ölablasssch B&s',
#     'Description': '6170-029-0500-a Seal oil drain plug B&amp;s'},
#    {'Item Number': '701765',
#     'Desctiption': 'Shb Faecher- A  8,4  Din6798 Vz',
#     'Description': 'Shb compartments- A 8.4 Din6798 Vz'},
#    {'Item Number': '703891',
#     'Desctiption': 'Shr 8x 35 Din933- 8.8 A3b',
#     'Description': 'Shr 8x 35 Din933- 8.8 A3b'},
#    {'Item Number': '51461810',
#     'Desctiption': 'Dichtung Auspuff 272293',
#     'Description': 'Exhaust gasket 272293'},
#    {'Item Number': '500073',
#     'Desctiption': 'Mu Skt Mit Sperrverz M8 Znni8f',
#     'Description': 'Mu Skt With Locking M8 Znni8f'},
#    {'Item Number': '476854',
#     'Desctiption': 'Krümmer Rechts 22 Hp Loncin Geschw',
#     'Description': 'Manifold Right 22 Hp Loncin Speed'},
#    {'Item Number': '476853',
#     'Desctiption': 'Krümmer Links 22 Hp Loncin Geschw',
#     'Description': 'Manifold Left 22 Hp Loncin Speed'},
#    {'Item Number': '464660',
#     'Desctiption': 'Dämpfer 2-zylinder Kpl',
#     'Description': 'Damper 2-cylinder cpl'},
#    {'Item Number': '706161',
#     'Desctiption': 'Mu  6kt  6   En1664- 8 A2k',
#     'Description': 'Mu 6kt 6 En1664- 8 A2k'},
#    {'Item Number': '705968',
#     'Desctiption': 'Shr 6x 16 Din 603- 8.8a3b',
#     'Description': 'Shr 6x 16 Din 603- 8.8a3b'},
#    {'Item Number': '468263',
#     'Desctiption': '6170-146-7300-a Abdeckblech Motor',
#     'Description': '6170-146-7300-a Engine cover plate'},
#    {'Item Number': '321126',
#     'Desctiption': 'Mutter Kasten- M 6-st Galvz+passi',
#     'Description': 'Nut box- M 6-st Galvz+passi'},
#    {'Item Number': '494220',
#     'Desctiption': 'Heat Protection Exhaust 2-cyl Lc',
#     'Description': 'Heat Protection Exhaust 2-cyl Lc'},
#    {'Item Number': '700555',
#     'Desctiption': 'Shr 6x 16 Din933- 8.8 Vz',
#     'Description': 'Shr 6x 16 Din933- 8.8 Vz'},
#    {'Item Number': '700200',
#     'Desctiption': 'Shb Faecher- J  6,4  Din6798 Vz',
#     'Description': 'Shb fan-J 6,4 Din6798 Vz'},
#    {'Item Number': '500207',
#     'Desctiption': 'Shr Skt M8x50 Sperrverz. A2k 8.8',
#     'Description': 'Shr Skt M8x50 locking delay. A2k 8.8'},
#    {'Item Number': '476823',
#     'Desctiption': '6170-764-8455-a Keilriemenscheibenhälfte',
#     'Description': '6170-764-8455-a V-belt pulley half'},
#    {'Item Number': '704128',
#     'Desctiption': 'Shr 8x 20 Din 603- 8.8a3b',
#     'Description': 'Shr 8x 20 Din 603- 8.8a3b'},
#    {'Item Number': '47317230',
#     'Desctiption': '6165-704-1810-a Bolzen F Verdrehs Verz',
#     'Description': '6165-704-1810-a Bolt F Torsion Galvanized'},
#    {'Item Number': '521684',
#     'Desctiption': 'Bbc-102 2-zylinder I-5217-36',
#     'Description': 'BBC-102 2-cylinder I-5217-36'},
#    {'Item Number': '468987',
#     'Desctiption': '9045-348-9050-a Schr Unf 7/16"x4,5" 10.9',
#     'Description': '9045-348-9050-a Screw Unf 7/16&quot;x4,5&quot; 10.9'},
#    {'Item Number': '47682430',
#     'Desctiption': '6170-708-2000-a Druckstück Motorwel Verz',
#     'Description': '6170-708-2000-a Thrust piece motor shaft galvanized'},
#    {'Item Number': '47686930',
#     'Desctiption': '6170-764-2830-a Motorwelle Kurz Verz',
#     'Description': '6170-764-2830-a Motor shaft short deceleration'},
#    {'Item Number': '704533',
#     'Desctiption': 'Mu 6kt  8   Din934- 8 A3b',
#     'Description': 'Mu 6kt 8 Din934- 8 A3b'},
#    {'Item Number': '705260',
#     'Desctiption': 'Sicherung Kl 12 Sxn 09  Vz',
#     'Description': 'Fuse Kl 12 Sxn 09 Vz'},
#    {'Item Number': '476678',
#     'Desctiption': '6165-704-2120-b Keilriemen Fahrantrieb',
#     'Description': '6165-704-2120-b V-belt drive'},
#    {'Item Number': '473233',
#     'Desctiption': '6165-764-1610-a Feder Fahrantrib',
#     'Description': '6165-764-1610-a Spring drive'},
#    {'Item Number': '46807430',
#     'Desctiption': '6170-704-2200-a Spannhebel Fahrant Verz',
#     'Description': '6170-704-2200-a Tension lever Fahrant Verz'},
#    {'Item Number': '471047',
#     'Desctiption': '6160-764-2801-a Distanzhülse',
#     'Description': '6160-764-2801-a Spacer sleeve'},
#    {'Item Number': '514220',
#     'Desctiption': 'Distanzscheibe',
#     'Description': 'Spacer'},
#    {'Item Number': '464454',
#     'Desctiption': '6170-760-1291-a Spannr Innen M.lager Et',
#     'Description': '6170-760-1291-a Tensioner inner M.bearing Et'},
#    {'Item Number': '375953',
#     'Desctiption': 'Shr Skt M8x40 Sperrverz. A2k 8.8',
#     'Description': 'Shr Skt M8x40 locking delay. A2k 8.8'},
#    {'Item Number': '464450',
#     'Desctiption': 'Abdeckung Umlenkrolle 69',
#     'Description': 'Cover pulley 69'},
#    {'Item Number': '704538',
#     'Desctiption': 'Shb A  8,4 Din125-st A3b',
#     'Description': 'Shb A 8,4 Din125-st A3b'},
#    {'Item Number': '514216',
#     'Desctiption': 'Zentrierhülse',
#     'Description': 'Centering sleeve'},
#    {'Item Number': '464453',
#     'Desctiption': '6170-760-6616-a Umlenkr. (m. Lager Et)',
#     'Description': '6170-760-6616-a diverter. (with bearing Et)'},
#    {'Item Number': '47101901',
#     'Desctiption': '6170-700-0415-a Vorderrad 15x6.00-6 Carl',
#     'Description': '6170-700-0415-a Front wheel 15x6.00-6 Carl'},
#    {'Item Number': '46807030',
#     'Desctiption': '6170-760-5005-a Achsschenkel R Ge Verz',
#     'Description': '6170-760-5005-a Steering knuckle R Ge Verz'},
#    {'Item Number': '47301030',
#     'Desctiption': '6165-763-5700-a Spurstange Av Verz',
#     'Description': '6165-763-5700-a Tie rod Av galv'},
#    {'Item Number': '46806830',
#     'Desctiption': '6170-760-5000-a Achsschenkel L Ge Verz',
#     'Description': '6170-760-5000-a Steering knuckle L Ge galvanized'},
#    {'Item Number': '473063',
#     'Desctiption': '6165-763-3011-a Lagerbuchse Lenkung Av',
#     'Description': '6165-763-3011-a Bearing bush steering Av'},
#    {'Item Number': '700719',
#     'Desctiption': 'Shb   21      433      Vz',
#     'Description': 'Shb 21 433 Vz'},
#    {'Item Number': '702724',
#     'Desctiption': 'Shb Sich 15  6799 Vz',
#     'Description': 'Shb Sich 15 6799 Vz'},
#    {'Item Number': '705419',
#     'Desctiption': 'Shr 12x 65 Din931- 8.8 Zn8disp',
#     'Description': 'Shr 12x 65 Din931- 8.8 Zn8disp'},
#    {'Item Number': '700203',
#     'Desctiption': 'Nippel 6x1 Keg 71412',
#     'Description': 'Nipple 6x1 Keg 71412'},
#    {'Item Number': '46865030',
#     'Desctiption': '6170-763-3010-a Lagerbuchse Verz',
#     'Description': '6170-763-3010-a Bearing bush galvanized'},
#    {'Item Number': '454453',
#     'Desctiption': 'Mu Sich- Biw M 12 A2k- 8 Mittelgesichert',
#     'Description': 'Mu Sich- Biw M 12 A2k- 8 Medium secured'},
#    {'Item Number': '704545',
#     'Desctiption': 'Shr 8x 25 Din933- 8.8 A3b',
#     'Description': 'Shr 8x 25 Din933- 8.8 A3b'},
#    {'Item Number': '468842',
#     'Desctiption': '9512-003-4660-a Rollenlager Vorderrad',
#     'Description': '9512-003-4660-a Roller bearing front wheel'},
#    {'Item Number': '461866',
#     'Desctiption': 'Schlauch 15x6,00-6 Tr13',
#     'Description': 'Tube 15x6.00-6 Tr13'},
#    {'Item Number': '461290',
#     'Desctiption': 'Scheibe 42mm Für Traktor',
#     'Description': 'Disc 42mm For Tractor'},
#    {'Item Number': '461289',
#     'Desctiption': 'Abdeckkappe Traktor',
#     'Description': 'Tractor cover cap'},
#    {'Item Number': '450263',
#     'Desctiption': 'Buchse Traktor Vorderrad',
#     'Description': 'Bushing tractor front wheel'},
#    {'Item Number': '461865',
#     'Desctiption': 'Reifen 15x6,00-6',
#     'Description': 'Tire 15x6.00-6'},
#    {'Item Number': '544578',
#     'Desctiption': 'Sfs Tapt 8x 16nr2021 Znni8f',
#     'Description': 'Sfs Tapt 8x 16nr2021 Znni8f'},
#    {'Item Number': '46151201',
#     'Desctiption': 'Rückwand Seitenauswurf 102 R9005',
#     'Description': 'Rear wall side discharge 102 R9005'},
#    {'Item Number': '49302230',
#     'Desctiption': 'Abstützung Traktor T3 E Verz',
#     'Description': 'Support tractor T3 E Verz'},
#    {'Item Number': '701011',
#     'Desctiption': 'Shr 8x 50 Din933- 8.8 Vz',
#     'Description': 'Shr 8x 50 Din933- 8.8 Vz'},
#    {'Item Number': '700545',
#     'Desctiption': 'Shr 8x 16 Din933- 8.8 Vz',
#     'Description': 'Shr 8x 16 Din933- 8.8 Vz'},
#    {'Item Number': '493023',
#     'Desctiption': 'Bypass Traktor E',
#     'Description': 'Bypass Tractor E'},
#    {'Item Number': '49309601',
#     'Desctiption': '6165-700-2401-a Vorderac Ges R9005 Av',
#     'Description': '6165-700-2401-a Vorderac Ges R9005 Av'},
#    {'Item Number': '700706',
#     'Desctiption': 'Shr 6x 60     603- 8.8 A3b',
#     'Description': 'Shr 6x 60 603- 8.8 A3b'},
#    {'Item Number': '513954',
#     'Desctiption': 'Mu Sich- Biw M 6  A3b- 8 Mittelgesichert',
#     'Description': 'Mu Sich- Biw M 6 A3b- 8 Medium secured'},
#    {'Item Number': '493005',
#     'Desctiption': 'Bremsarretierung E',
#     'Description': 'Brake lock E'},
#    {'Item Number': '468641',
#     'Desctiption': '6170-703-5140-a Feder Bremsarretierung',
#     'Description': '6170-703-5140-a Spring brake lock'},
#    {'Item Number': '473132',
#     'Desctiption': '6165-703-5110-a Rückholfeder Bre Av',
#     'Description': '6165-703-5110-a Return Spring Bre Av'},
#    {'Item Number': '476591',
#     'Desctiption': 'Abdeckung Fusspedal Bremse',
#     'Description': 'Cover foot pedal brake'},
#    {'Item Number': '476590',
#     'Desctiption': 'Abdeckung Fusspedal Vor- U Rückwärts',
#     'Description': 'Cover foot pedal forward and backward'},
#    {'Item Number': '607801',
#     'Desctiption': 'Schnellbefestiger10sxn26 Vz',
#     'Description': 'Quick fastener10sxn26 Vz'},
#    {'Item Number': '49300430',
#     'Desctiption': 'Bremspedal Traktor Geschw E Verz',
#     'Description': 'Brake pedal tractor speed deceleration'},
#    {'Item Number': '47302730',
#     'Desctiption': '6170-703-8910-a Lagerungpl F Pe Av Verz',
#     'Description': '6170-703-8910-a Storage Pl F Pe Av Dist'},
#    {'Item Number': '47308830',
#     'Desctiption': 'Mitnehmer Gasansteuerung A Verz',
#     'Description': 'Driver gas control A delay'},
#    {'Item Number': '47308530',
#     'Desctiption': 'Mitnahmebolzen Fahrantrieb A Verz',
#     'Description': 'Driving pin travel drive A Verz'},
#    {'Item Number': '700150',
#     'Desctiption': 'Shb   8,4 9021-st  Vz',
#     'Description': 'Shb 8,4 9021-st Vz'},
#    {'Item Number': '704539',
#     'Desctiption': 'Shb A 10,5 Din125-st A3b',
#     'Description': 'Shb A 10,5 Din125-st A3b'},
#    {'Item Number': '468172',
#     'Desctiption': '6170-703-6410-a Druckfeder Bremse K46',
#     'Description': '6170-703-6410-a Pressure spring brake K46'},
#    {'Item Number': '47303130',
#     'Desctiption': '6165-703-1710-a Bremsstan T2 Ge  Verz',
#     'Description': '6165-703-1710-a Brake rod T2 Ge Verz'},
#    {'Item Number': '473149',
#     'Desctiption': '6165-763-0410-a Bügel Bremsarreti Av',
#     'Description': '6165-763-0410-a Bracket Brake Arreti Av'},
#    {'Item Number': '49300330',
#     'Desctiption': 'Gaspedal Traktor Geschw E Verz',
#     'Description': 'Accelerator Tractor Speed \u200b\u200bDeceleration'},
#    {'Item Number': '704536',
#     'Desctiption': 'Mu 6kt  6    Din985- 8 A3b',
#     'Description': 'Mu 6kt 6 Din985- 8 A3b'},
#    {'Item Number': '47304230',
#     'Desctiption': '6165-704-1800-a Schraube Gashebel Verz',
#     'Description': '6165-704-1800-a Screw throttle lever'},
#    {'Item Number': '705900',
#     'Desctiption': 'Mu 6kt  8  En1663   8  A2k',
#     'Description': 'Mu 6kt 8 En1663 8 A2k'},
#    {'Item Number': '47316730',
#     'Desctiption': '6165-704-9800-a Schaltss Gasa V Verz',
#     'Description': '6165-704-9800-a Switch Gasa V Delay'},
#    {'Item Number': '476001',
#     'Desctiption': 'Gear T3-ahbf-2x3c-1tx4',
#     'Description': 'GearT3-ahbf-2x3c-1tx4'},
#    {'Item Number': '606135',
#     'Desctiption': 'Shr Duo-tapt 5x10-c Torx A3b',
#     'Description': 'Shr Duo-tapt 5x10-c Torx A3b'},
#    {'Item Number': '473609',
#     'Desctiption': '6170-403-2310-a Halter Getriebeschalter',
#     'Description': '6170-403-2310-a Gear switch bracket'},
#    {'Item Number': '473610',
#     'Desctiption': '6170-647-1100-a Winkelstück Schalterb',
#     'Description': '6170-647-1100-a Angle piece switch'},
#    {'Item Number': '514313',
#     'Desctiption': 'Passfeder 3/16"x3/16"x2 1/4',
#     'Description': 'Key 3/16&quot;x3/16&quot;x2 1/4'},
#    {'Item Number': '473043',
#     'Desctiption': '6165-764-2800-a Distanzbuchse Av',
#     'Description': '6165-764-2800-a Spacer bush Av'},
#    {'Item Number': '700303',
#     'Desctiption': 'Shr  8x 70 Din931- 8.8 Vz',
#     'Description': 'Shr 8x 70 Din931- 8.8 Vz'},
#    {'Item Number': '47101801',
#     'Desctiption': '6170-700-0435-a Hinterrad 18x8,50-8 Carl',
#     'Description': '6170-700-0435-a Rear wheel 18x8,50-8 Carl'},
#    {'Item Number': '493035',
#     'Desctiption': 'Kugelgriff M5 E',
#     'Description': 'Ball handle M5 E'},
#    {'Item Number': '473174',
#     'Desctiption': '6165-703-6900-a Gegenha Lenksäule Av',
#     'Description': '6165-703-6900-a Counterweight steering column Av'},
#    {'Item Number': '468870',
#     'Desctiption': '0000-704-6703-a Schlauch 20x10,0-8',
#     'Description': '0000-704-6703-a Hose 20x10,0-8'},
#    {'Item Number': '471020',
#     'Desctiption': '6170-704-9525-a Reifen 18x8,50-8 Carlisl',
#     'Description': '6170-704-9525-a Tire 18x8.50-8 Carlisl'},
#    {'Item Number': '47304830',
#     'Desctiption': '6165-760-7800-a Höhenverst Ge Av Verz',
#     'Description': '6165-760-7800-a Height adjustment Ge Av Verz'},
#    {'Item Number': '473399',
#     'Desctiption': '6165-703-2000-a Kugelmutter M10 A2k',
#     'Description': '6165-703-2000-a ball nut M10 A2k'},
#    {'Item Number': '47305030',
#     'Desctiption': '6165-703-4610-a Verbindungsst Av Verz',
#     'Description': '6165-703-4610-a Connection St Av Directory'},
#    {'Item Number': '47307830',
#     'Desctiption': '6165-763-5600-a Schwinge Höhe Av Verz',
#     'Description': '6165-763-5600-a Swing arm height Av deg'},
#    {'Item Number': '473360',
#     'Desctiption': '6165-703-5100-a Feder Höhenverstel',
#     'Description': '6165-703-5100-a Spring height adjustment'},
#    {'Item Number': '473217',
#     'Desctiption': '6165-703-9500-a Rasterung Höhenv',
#     'Description': '6165-703-9500-a Grid height'},
#    {'Item Number': '47317630',
#     'Desctiption': '6165-703-4600-a Verbindungsst Mäh Verz',
#     'Description': '6165-703-4600-a Connecting rod mower'},
#    {'Item Number': '703808',
#     'Desctiption': 'Mu 6kt  12   Din934- 8 A3b',
#     'Description': 'Mu 6kt 12 Din934- 8 A3b'},
#    {'Item Number': '473232',
#     'Desctiption': '6165-703-5120-a Feder Vordere Schw',
#     'Description': '6165-703-5120-a Spring Front Sw'},
#    {'Item Number': '47684902',
#     'Desctiption': 'Mähdeck 110cm Sa Geschw Al-ko R3000',
#     'Description': 'Mower deck 110cm Sa speed Al-ko R3000'},
#    {'Item Number': '476695',
#     'Desctiption': 'Federstecker (ø3)',
#     'Description': 'Spring plug (ø3)'},
#    {'Item Number': '514174',
#     'Desctiption': 'Schaltgriff',
#     'Description': 'Shift handle'},
#    {'Item Number': '49402130',
#     'Desctiption': "'HÖhenverstellh. Geschw GekrÖpft Com Verz'",
#     'Description': '&#39;Height Adjustment Speed \u200b\u200bCranked Com Delay&#39;'},
#    {'Item Number': '473072',
#     'Desctiption': '6165-704-2110-a Riem Messera 110  Sa Av',
#     'Description': '6165-704-2110-a Riem Messera 110 Sa Av'},
#    {'Item Number': '515246',
#     'Desctiption': 'Scheibe 30/10,5 X 5',
#     'Description': 'Disc 30/10.5 X 5'},
#    {'Item Number': '700702',
#     'Desctiption': 'Shr 6x 25 Din933- 8.8 Vz',
#     'Description': 'Shr 6x 25 Din933- 8.8 Vz'},
#    {'Item Number': '473337',
#     'Desctiption': 'Messerhalter Al-ko',
#     'Description': 'Knife holder Al-ko'},
#    {'Item Number': '476662',
#     'Desctiption': 'Messer 110cm Sa Al-ko',
#     'Description': 'Knife 110cm Sa Al-ko'},
#    {'Item Number': '473405',
#     'Desctiption': '6165-764-8400-a Riemensch Mähd 148',
#     'Description': '6165-764-8400-a Riemensch mower 148'},
#    {'Item Number': '47306630',
#     'Desctiption': '6165-703-0900-a Stecker Auswu Av Verz',
#     'Description': '6165-703-0900-a Plug Auswu Av Verz'},
#    {'Item Number': '521940',
#     'Desctiption': 'Schenkelfeder Auswurfklappe',
#     'Description': 'Leg spring ejection flap'},
#    {'Item Number': '473054',
#     'Desctiption': '6165-706-2400-a Auswurfkl 110',
#     'Description': '6165-706-2400-a Ejector 110'},
#    {'Item Number': '468700',
#     'Desctiption': '6170-967-4435-a Aufkleber Mähdeck',
#     'Description': '6170-967-4435-a Mower deck sticker'},
#    {'Item Number': '473343',
#     'Desctiption': '6907-766-8320-a Mulch-verschl 110 A/v',
#     'Description': '6907-766-8320-a Mulching 110 A/v'},
#    {'Item Number': '473510',
#     'Desctiption': '6907-706-0200-a Federstecker Mulchv',
#     'Description': '6907-706-0200-a Spring plug Mulchv'},
#    {'Item Number': '476686',
#     'Desctiption': '6165-780-1200-a Zugfeder Mit Schlauch',
#     'Description': '6165-780-1200-a Tension Spring With Hose'},
#    {'Item Number': '47321230',
#     'Desctiption': '6165-760-0800-a Spannwippe Gesch Verz',
#     'Description': '6165-760-0800-a clamping rocker Gesch Verz'},
#    {'Item Number': '473402',
#     'Desctiption': '6165-760-1200-a Rückenr 92 Mit Lager Sa',
#     'Description': '6165-760-1200-a Back 92 With Bearing Sa'},
#    {'Item Number': '47341930',
#     'Desctiption': '6165-764-2830-a Distanzb Spannr Verz',
#     'Description': '6165-764-2830-a Distance clamping device'},
#    {'Item Number': '47342030',
#     'Desctiption': '6165-764-2840-a Distanzb Umlenk Verz',
#     'Description': '6165-764-2840-a Distance deflection'},
#    {'Item Number': '704337',
#     'Desctiption': 'Shr10x 60 Din933- 8.8 A3b',
#     'Description': 'Shr10x 60 Din933- 8.8 A3b'},
#    {'Item Number': '458568',
#     'Desctiption': '9039-488-1839-a Shr M8x25 Din7500 Sperrz',
#     'Description': '9039-488-1839-a Shr M8x25 Din7500 locking'},
#    {'Item Number': '514175',
#     'Desctiption': '6170-702-6910-a Lagerbock Mähantrieb',
#     'Description': '6170-702-6910-a Bearing bracket for mowing drive'},
#    {'Item Number': '46835530',
#     'Desctiption': '6170-702-0710-b Messerw Flansch Verz',
#     'Description': '6170-702-0710-b knife flange galvanized'},
#    {'Item Number': '476634',
#     'Desctiption': '9503-003-6841-b Lag Kug   6205 2rs (hch)',
#     'Description': '9503-003-6841-b Lag Kug 6205 2rs (hch)'},
#    {'Item Number': '464555',
#     'Desctiption': 'O-ring D23x1,5 Nbr 70 Shore A',
#     'Description': 'O-ring D23x1,5 Nbr 70 Shore A'},
#    {'Item Number': '468353',
#     'Desctiption': '6170-702-2210-a Lagerdichtung',
#     'Description': '6170-702-2210-a Bearing seal'},
#    {'Item Number': '468102',
#     'Desctiption': '6170-702-0600-a Mitnehmer Riemens',
#     'Description': '6170-702-0600-a Drive belt'},
#    {'Item Number': '468100',
#     'Desctiption': '6160-764-8400-b Keilriemenscheibenhäl',
#     'Description': '6160-764-8400-b V-belt pulley holder'},
#    {'Item Number': '468101',
#     'Desctiption': '6170-702-1800-a Scheibe',
#     'Description': '6170-702-1800-a Disc'},
#    {'Item Number': '468469',
#     'Desctiption': '0000-702-6600-a Spannscheibe 10x4 Viking',
#     'Description': '0000-702-6600-a Tension washer 10x4 Viking'},
#    {'Item Number': '47340301',
#     'Desctiption': '6165-706-8200-a Klappsch Emak Av R9005',
#     'Description': '6165-706-8200-a Klappsch Emak Av R9005'},
#    {'Item Number': '473515',
#     'Desctiption': '6165-706-9500-a Schlitzschra F Klapps',
#     'Description': '6165-706-9500-a Slotted screw F folding'},
#    {'Item Number': '473415',
#     'Desctiption': '6165-703-5130-a Zugfeder Klappschutz',
#     'Description': '6165-703-5130-a Tension spring folding protection'},
#    {'Item Number': '47350730',
#     'Desctiption': '6165-702-4400-a Distanzhülse Verz',
#     'Description': '6165-702-4400-a Spacer sleeve galvanized'},
#    {'Item Number': '47317701',
#     'Desctiption': '6165-706-0810-a Riemenabd Li 110cm Sa Av',
#     'Description': '6165-706-0810-a Belt cover Li 110cm Sa Av'},
#    {'Item Number': '47311201',
#     'Desctiption': '6165-780-2020-a Riemenabd Bew Av R9005',
#     'Description': '6165-780-2020-a Belt cover Bew Av R9005'},
#    {'Item Number': '471071',
#     'Desctiption': '9039-488-1289-a Pt-k Tx 6x25 7500 Znni8f',
#     'Description': '9039-488-1289-a Pt-k Tx 6x25 7500 Znni8f'},
#    {'Item Number': '47317801',
#     'Desctiption': '6165-706-0815-a Riemenabd Re 110cm Sa Av',
#     'Description': '6165-706-0815-a Belt cover R 110cm Sa Av'},
#    {'Item Number': '706611',
#     'Desctiption': 'Sti Iso 8741- 6x45-st A2k',
#     'Description': 'Sti Iso 8741- 6x45-st A2k'},
#    {'Item Number': '514839',
#     'Desctiption': 'Benzintank',
#     'Description': 'Petrol tank'},
#    {'Item Number': '476109',
#     'Desctiption': 'Tankdeckel Kpl Neutral',
#     'Description': 'Tank cap cpl neutral'},
#    {'Item Number': '493055',
#     'Desctiption': 'Batteriekasten E',
#     'Description': 'Battery box E'},
#    {'Item Number': '514818',
#     'Desctiption': 'Befestigungsgummi',
#     'Description': 'Fastening rubber'},
#    {'Item Number': '451001',
#     'Desctiption': 'Batteriepolabdec Für Batterie',
#     'Description': 'Battery terminal cover for battery'},
#    {'Item Number': '493414',
#     'Desctiption': 'Batterie TCS SL12-20 (12V/20Ah) -(493589)',
#     'Description': 'Battery TCS SL12-20 (12V/20Ah) -(493589)'},
#    {'Item Number': '493039',
#     'Desctiption': 'Verriegelungsdraht Motorhaube',
#     'Description': 'Hood locking wire'},
#    {'Item Number': '49300830',
#     'Desctiption': 'Lenkungsholm Traktor Verz E',
#     'Description': 'Steering handle tractor Verz E'},
#    {'Item Number': '514197',
#     'Desctiption': 'Ep-bundbuchse',
#     'Description': 'EP-collar socket'},
#    {'Item Number': '493073',
#     'Desctiption': 'Stützblech Traktor E',
#     'Description': 'Support plate tractor E'},
#    {'Item Number': '701489',
#     'Desctiption': 'Shr 6x 35 Din933- 8.8 Vz',
#     'Description': 'Shr 6x 35 Din933- 8.8 Vz'},
#    {'Item Number': '700553',
#     'Desctiption': 'Shr 6x 40 Din933- 8.8 Vz',
#     'Description': 'Shr 6x 40 Din933- 8.8 Vz'},
#    {'Item Number': '493079',
#     'Desctiption': 'Einrastblech E',
#     'Description': 'Snap-in plate E'},
#    {'Item Number': '49302130',
#     'Desctiption': 'Lenksäule E Verz',
#     'Description': 'Steering column E Verz'},
#    {'Item Number': '704275',
#     'Desctiption': 'Sti Span Iso8748-st 6x24',
#     'Description': 'Sti Span Iso8748-st 6x24'},
#    {'Item Number': '705614',
#     'Desctiption': 'Shr 8x 40 Iso10642 - 8.8 A2k',
#     'Description': 'Shr 8x 40 Iso10642 - 8.8 A2k'},
#    {'Item Number': '51400930',
#     'Desctiption': 'Lenkungsritzel Verz',
#     'Description': 'Steering pinion gear'},
#    {'Item Number': '464305',
#     'Desctiption': 'Verbindungssteil Lenksäule',
#     'Description': 'Steering column connecting part'},
#    {'Item Number': '473491',
#     'Desctiption': 'Gasgriff 2k Al-ko',
#     'Description': 'Throttle grip 2k Al-ko'},
#    {'Item Number': '700119',
#     'Desctiption': 'Mu 6kt  5      Din985- 8 Vz',
#     'Description': 'Mu 6kt 5 Din985- 8 Vz'},
#    {'Item Number': '701172',
#     'Desctiption': 'Shr 5x 12 Din933- 8.8 Vz',
#     'Description': 'Shr 5x 12 Din933- 8.8 Vz'},
#    {'Item Number': '543560',
#     'Desctiption': 'Shr Pt-k 40x10 1451 A2k',
#     'Description': 'Shr Pt-k 40x10 1451 A2k'},
#    {'Item Number': '521729',
#     'Desctiption': 'Gasfernbedienung 2-zylinder',
#     'Description': 'Gas remote control 2-cylinder'},
#    {'Item Number': '461587',
#     'Desctiption': 'Schrauben Für Batterie Csb Gp',
#     'Description': 'Screws For Battery Csb Gp'},
#    {'Item Number': '468230',
#     'Desctiption': '6170-703-6400-a Sitzfeder',
#     'Description': '6170-703-6400-a Seat spring'},
#    {'Item Number': '704546',
#     'Desctiption': 'Shr 8x 20 Din933- 8.8 A3b',
#     'Description': 'Shr 8x 20 Din933- 8.8 A3b'},
#    {'Item Number': '514346',
#     'Desctiption': 'Abdeckkappe D-35 Ral9005',
#     'Description': 'Cover cap D-35 Ral9005'},
#    {'Item Number': '700051',
#     'Desctiption': 'Shr  8x 20     Din912- 8.8 Vz',
#     'Description': 'Shr 8x 20 Din912- 8.8 Vz'},
#    {'Item Number': '52172730',
#     'Desctiption': 'Distanzbuchse Verz',
#     'Description': 'Spacer bushing galvanized'},
#    {'Item Number': '521480',
#     'Desctiption': 'Flügelschraube M8x20',
#     'Description': 'Wing screw M8x20'},
#    {'Item Number': '700483',
#     'Desctiption': 'Shr 6x 12 Din933- 8.8 Vz',
#     'Description': 'Shr 6x 12 Din933- 8.8 Vz'},
#    {'Item Number': '46411030',
#     'Desctiption': 'Lagerstange Sitzkonsole Verz',
#     'Description': 'Bearing rod seat console galvanized'},
#    {'Item Number': '521302',
#     'Desctiption': 'Verstellkonsole Sitz T800',
#     'Description': 'Seat adjustment console T800'},
#    {'Item Number': '46189630',
#     'Desctiption': 'Sitzschalterfeder Härten',
#     'Description': 'Seat switch spring hardening'},
#    {'Item Number': '468680',
#     'Desctiption': '6170-430-0520-a Drucks 6700-50b',
#     'Description': '6170-430-0520-a Print 6700-50b'},
#    {'Item Number': '52174130',
#     'Desctiption': 'Anschlagwinkel Fernbedienung Verz',
#     'Description': 'Stop angle remote control'},
#    {'Item Number': '468783',
#     'Desctiption': '6170-180-2610-a Chockerzug Kawa 580',
#     'Description': '6170-180-2610-a Chocker train Kawa 580'},
#    {'Item Number': '701918',
#     'Desctiption': 'Shb Sich  6  6799 Zn',
#     'Description': 'Shb Sich 6 6799 Zn'},
#    {'Item Number': '461895',
#     'Desctiption': 'Sitzschalterblech',
#     'Description': 'Seat switch plate'},
#    {'Item Number': '461500',
#     'Desctiption': 'Zugfeder Für Kupplung Fahran+sitz',
#     'Description': 'Tension spring for clutch driver+seat'},
#    {'Item Number': '543474',
#     'Desctiption': 'Sl Sicherung 8sxno8',
#     'Description': 'Sl fuse 8sxno8'},
#    {'Item Number': '476712',
#     'Desctiption': '6005-435-0410-a Endschalter No Ip67',
#     'Description': '6005-435-0410-a Limit switch No Ip67'},
#    {'Item Number': '701352',
#     'Desctiption': 'Mu 6kt  4      Din985- 8 Vz',
#     'Description': 'Mu 6kt 4 Din985- 8 Vz'},
#    {'Item Number': '706096',
#     'Desctiption': 'Shr 4x 12 Iso10642 - 8.8 A2k',
#     'Description': 'Shr 4x 12 Iso10642 - 8.8 A2k'},
#    {'Item Number': '473942',
#     'Desctiption': 'Elektromodul Rückwärts Al-ko',
#     'Description': 'Electric module reverse Al-ko'},
#    {'Item Number': '468603',
#     'Desctiption': '6170-430-2400-a Zündanlassschalter 4 Po',
#     'Description': '6170-430-2400-a Ignition switch 4 po'},
#    {'Item Number': '473258',
#     'Desctiption': 'Zündschlüssel M Kappe Al-ko Kpl',
#     'Description': 'Ignition key M cap Al-ko cpl'},
#    {'Item Number': '473587',
#     'Desctiption': 'Drucktaster Rund A',
#     'Description': 'Push button round A'},
#    {'Item Number': '521819',
#     'Desctiption': 'Stecksicherung 15 A',
#     'Description': 'Plug-in fuse 15 A'},
#    {'Item Number': '521821',
#     'Desctiption': 'Stecksicherung 10 A',
#     'Description': 'Plug-in fuse 10 A'},
#    {'Item Number': '47350201',
#     'Desctiption': '6165-403-2500-a Abdeck 150 Sich Sa R9005',
#     'Description': '6165-403-2500-a Cover 150 Self Sa R9005'},
#    {'Item Number': '700106',
#     'Desctiption': 'Mu  6kt  5   Din934- 8 Vz',
#     'Description': 'Mu 6kt 5 Din934- 8 Vz'},
#    {'Item Number': '700126',
#     'Desctiption': 'Rg Fed- B 5 Din127 Vz',
#     'Description': 'Rg Fed-B 5 Din127 Vz'},
#    {'Item Number': '703106',
#     'Desctiption': 'Shr 5x 25 Din933- 8.8 Vz',
#     'Description': 'Shr 5x 25 Din933- 8.8 Vz'},
#    {'Item Number': '468678',
#     'Desctiption': '6170-437-0800-a Siche Hsb Fuse Rated 32v',
#     'Description': '6170-437-0800-a Siche Hsb Fuse Rated 32v'},
#    {'Item Number': '521849',
#     'Desctiption': 'Relais 12v - 20/30a',
#     'Description': 'Relay 12v - 20/30a'},
#    {'Item Number': '473619',
#     'Desctiption': 'Kabel Hauptsicherung Batterie Ha',
#     'Description': 'Cable main fuse battery Ha'},
#    {'Item Number': '521375',
#     'Desctiption': 'Skt-mu.+sperrz.1/4"-20 Un  8.8',
#     'Description': 'Skt-mu.+locking 1/4&quot;-20 Un 8.8'},
#    {'Item Number': '521363',
#     'Desctiption': 'Kabel Rot Starter/relais',
#     'Description': 'Cable Red Starter/relay'},
#    {'Item Number': '473620',
#     'Desctiption': 'Kabel Hauptsicherung Starterr Ha',
#     'Description': 'Cable main fuse starter Ha'},
#    {'Item Number': '700701',
#     'Desctiption': 'Shr 6x 20 Din933- 8.8 Vz',
#     'Description': 'Shr 6x 20 Din933- 8.8 Vz'},
#    {'Item Number': '468981',
#     'Desctiption': '6160-405-8000-a Isolierplatte Startrel',
#     'Description': '6160-405-8000-a Insulating plate Startrel'},
#    {'Item Number': '521361',
#     'Desctiption': 'Starterrelais 12v/200amper',
#     'Description': 'Starter relay 12v/200amper'},
#    {'Item Number': '473661',
#     'Desctiption': '6170-440-0500-a Adapter Emak',
#     'Description': '6170-440-0500-a Adapter Emak'},
#    {'Item Number': '700147',
#     'Desctiption': 'Shb   5,3 9021-st  Vz',
#     'Description': 'Shb 5,3 9021-st Vz'}],
#   'Img Url': 'https://alko-garden.de/out/media/exploded_views/2023/12/2023-12-127724-1.gif',
#   'Img Filename': 'SGL0000075639-Gasoline lawn tractor T 18-111.4 HDS-A V2.jpg'},
#  {'SGL': 'SGL0000075703',
#   'Catalog': 'Tractor T15-93.7 Hd-a Comfort',
#   'Parts': [{'Item Number': '493017',
#     'Desctiption': 'Kabelbaum Hauptstrang Ha  Traktor',
#     'Description': 'Kabelbaum Hauptstrang Ha  Traktor'},
#    {'Item Number': '473661',
#     'Desctiption': '6170-440-0500-a Adapter Emak',
#     'Description': '6170-440-0500-a Adapter Emak'},
#    {'Item Number': '473619',
#     'Desctiption': 'Kabel Hauptsicherung Batterie Ha',
#     'Description': 'Kabel Hauptsicherung Batterie Ha'},
#    {'Item Number': '473620',
#     'Desctiption': 'Kabel Hauptsicherung Starterr Ha',
#     'Description': 'Kabel Hauptsicherung Starterr Ha'},
#    {'Item Number': '521363',
#     'Desctiption': 'Kabel Rot Starter/relais',
#     'Description': 'Kabel Rot Starter/relais'},
#    {'Item Number': '51400402',
#     'Desctiption': '51400402',
#     'Description': '51400402'},
#    {'Item Number': '457760',
#     'Desctiption': '9039-490-0994-a Gew.forms. Din7500-m6x16',
#     'Description': '9039-490-0994-a Gew.forms. Din7500-m6x16'},
#    {'Item Number': '51400502',
#     'Desctiption': '51400502',
#     'Description': '51400502'},
#    {'Item Number': '521085',
#     'Desctiption': 'Abdeckung Höhenverstel.tamp Y-silber',
#     'Description': 'Abdeckung Höhenverstel.tamp Y-silber'},
#    {'Item Number': '514544',
#     'Desctiption': 'Shr Pt-kb 60x30 Wn1451 A2k',
#     'Description': 'Shr Pt-kb 60x30 Wn1451 A2k'},
#    {'Item Number': '473781',
#     'Desctiption': 'Mähdeckschalter Al-ko Tamp',
#     'Description': 'Mähdeckschalter Al-ko Tamp'},
#    {'Item Number': '49300601',
#     'Desctiption': 'Trittplatte Rechts R9005',
#     'Description': 'Trittplatte Rechts R9005'},
#    {'Item Number': '521676',
#     'Desctiption': 'Sheet Metal Nut 4,8 Mm  No 013832',
#     'Description': 'Sheet Metal Nut 4,8 Mm  No 013832'},
#    {'Item Number': '468569',
#     'Desctiption': '9102-090-3781-a L Torx Key 4,8x16 F A3r',
#     'Description': '9102-090-3781-a L Torx Key 4,8x16 F A3r'},
#    {'Item Number': '49300701',
#     'Desctiption': 'Trittplatte Links R9005',
#     'Description': 'Trittplatte Links R9005'},
#    {'Item Number': '49308001',
#     'Desctiption': 'Konsole Motorhaube E R9005',
#     'Description': 'Konsole Motorhaube E R9005'},
#    {'Item Number': '746005',
#     'Desctiption': 'Bolt 6x 20 7985- 4.8-torx A3r',
#     'Description': 'Bolt 6x 20 7985- 4.8-torx A3r'},
#    {'Item Number': '705657', 'Desctiption': 'Washer', 'Description': 'Washer'},
#    {'Item Number': '514166', 'Desctiption': 'Seat 1', 'Description': 'Seat 1'},
#    {'Item Number': '46177401',
#     'Desctiption': 'Abdeckung Schaltkulisse Fussc R9005',
#     'Description': 'Abdeckung Schaltkulisse Fussc R9005'},
#    {'Item Number': '518482',
#     'Desctiption': 'Screw Pt-k 50x18 1451 A2k',
#     'Description': 'Screw Pt-k 50x18 1451 A2k'},
#    {'Item Number': '493164',
#     'Desctiption': 'Bedienkonsole Tamp Y-silber E 1zy',
#     'Description': 'Bedienkonsole Tamp Y-silber E 1zy'},
#    {'Item Number': '464307',
#     'Desctiption': 'Lenkrad Kpl',
#     'Description': 'Lenkrad Kpl'},
#    {'Item Number': '46111802',
#     'Desctiption': 'Cover Cap For Steering Wheel R3000',
#     'Description': 'Cover Cap For Steering Wheel R3000'},
#    {'Item Number': '701508',
#     'Desctiption': 'Screw 10x70 Din933- 8.8 Zp',
#     'Description': 'Screw 10x70 Din933- 8.8 Zp'},
#    {'Item Number': '705284',
#     'Desctiption': 'Cup Spring 28  X10,2x1,5  2093',
#     'Description': 'Cup Spring 28  X10,2x1,5  2093'},
#    {'Item Number': '51524630',
#     'Desctiption': '51524630',
#     'Description': '51524630'},
#    {'Item Number': '468878',
#     'Desctiption': 'Shr Pt-kb 50x12 Wn1451 Znni8f',
#     'Description': 'Shr Pt-kb 50x12 Wn1451 Znni8f'},
#    {'Item Number': '521724',
#     'Desctiption': 'Abdeckung Für Schalter Box U Mähd',
#     'Description': 'Abdeckung Für Schalter Box U Mähd'},
#    {'Item Number': '52113801',
#     'Desctiption': 'Abdeckkappe Mittelkonsole R9005',
#     'Description': 'Abdeckkappe Mittelkonsole R9005'},
#    {'Item Number': '468673',
#     'Desctiption': '9302-929-0500-a Verschlussstopfen 16mm',
#     'Description': '9302-929-0500-a Verschlussstopfen 16mm'},
#    {'Item Number': '49305902',
#     'Desctiption': 'Side Part Right Cover R3000 E',
#     'Description': 'Side Part Right Cover R3000 E'},
#    {'Item Number': '468908',
#     'Desctiption': '9104-003-4139-a S Pt-kb60x25 1451 Znni8f',
#     'Description': '9104-003-4139-a S Pt-kb60x25 1451 Znni8f'},
#    {'Item Number': '49305802',
#     'Desctiption': 'Seitenteil Links Haube R3000 E',
#     'Description': 'Seitenteil Links Haube R3000 E'},
#    {'Item Number': '510759',
#     'Desctiption': 'Screw (retainer)',
#     'Description': 'Screw (retainer)'},
#    {'Item Number': '493060',
#     'Desctiption': 'Motorhaube Lichtscheibe E',
#     'Description': 'Motorhaube Lichtscheibe E'},
#    {'Item Number': '49305702',
#     'Desctiption': 'Front Part Cover Al-ko R3000 E',
#     'Description': 'Front Part Cover Al-ko R3000 E'},
#    {'Item Number': '521460',
#     'Desctiption': 'Hinge Sheet Cover',
#     'Description': 'Hinge Sheet Cover'},
#    {'Item Number': '49305601',
#     'Desctiption': 'Upper Part Cover Al-ko R9005 E',
#     'Description': 'Upper Part Cover Al-ko R9005 E'},
#    {'Item Number': '526611',
#     'Desctiption': 'Torx Screw 60x14 Wn1451 A2k',
#     'Description': 'Torx Screw 60x14 Wn1451 A2k'},
#    {'Item Number': '700148',
#     'Desctiption': 'Washer A 6,4 9021-st Vz',
#     'Description': 'Washer A 6,4 9021-st Vz'},
#    {'Item Number': '51441930',
#     'Desctiption': 'Spring Steel Wire',
#     'Description': 'Spring Steel Wire'},
#    {'Item Number': '49306101',
#     'Desctiption': 'Motorhaube Blende R9005 E',
#     'Description': 'Motorhaube Blende R9005 E'},
#    {'Item Number': '493089',
#     'Desctiption': 'Verschlussstopfen Traktor',
#     'Description': 'Verschlussstopfen Traktor'},
#    {'Item Number': '344014',
#     'Desctiption': 'Screw Pt-kb 35x10 Wn1423 A2k',
#     'Description': 'Screw Pt-kb 35x10 Wn1423 A2k'},
#    {'Item Number': '49308730',
#     'Desctiption': 'Führungsblech Seiten Motorh E Verz',
#     'Description': 'Führungsblech Seiten Motorh E Verz'},
#    {'Item Number': '544515',
#     'Desctiption': 'Schlauchklemme 14,5  B&s  93053',
#     'Description': 'Schlauchklemme 14,5  B&s  93053'},
#    {'Item Number': '51437910',
#     'Desctiption': 'Gasoline Hose Cutting',
#     'Description': 'Gasoline Hose Cutting'},
#    {'Item Number': '464659',
#     'Desctiption': 'Dämpfer 1-zylinder Kpl',
#     'Description': 'Dämpfer 1-zylinder Kpl'},
#    {'Item Number': '706161',
#     'Desctiption': 'Nut   6     En1664- 8  A2k',
#     'Description': 'Nut   6     En1664- 8  A2k'},
#    {'Item Number': '705968',
#     'Desctiption': 'Bolt  6x 16     603- 8.8a3b',
#     'Description': 'Bolt  6x 16     603- 8.8a3b'},
#    {'Item Number': '468263',
#     'Desctiption': '6170-146-7300-a Abdeckblech Motor',
#     'Description': '6170-146-7300-a Abdeckblech Motor'},
#    {'Item Number': '523134',
#     'Desctiption': 'Bolt Sfs-tapt M6x12 2021 A2k',
#     'Description': 'Bolt Sfs-tapt M6x12 2021 A2k'},
#    {'Item Number': '321126',
#     'Desctiption': 'Mutter Kasten- M 6-st Galvz+passi',
#     'Description': 'Mutter Kasten- M 6-st Galvz+passi'},
#    {'Item Number': '468305',
#     'Desctiption': '6160-145-3700-a Hitzeblech Auspuff 1zy',
#     'Description': '6160-145-3700-a Hitzeblech Auspuff 1zy'},
#    {'Item Number': '700200',
#     'Desctiption': 'Washer Lock J  6,4  Din6798 Zp',
#     'Description': 'Washer Lock J  6,4  Din6798 Zp'},
#    {'Item Number': '700555',
#     'Desctiption': 'Screw 6x 16 Din933- 8.8 Vz',
#     'Description': 'Screw 6x 16 Din933- 8.8 Vz'},
#    {'Item Number': '49300101',
#     'Desctiption': 'Rahmen 93-103 Geschw E R9005',
#     'Description': 'Rahmen 93-103 Geschw E R9005'},
#    {'Item Number': '476206',
#     'Desctiption': 'Benzinschlauch Für Loncin Motor',
#     'Description': 'Benzinschlauch Für Loncin Motor'},
#    {'Item Number': '702254',
#     'Desctiption': 'Washer Lock A 10,5  Din6798 Zp',
#     'Description': 'Washer Lock A 10,5  Din6798 Zp'},
#    {'Item Number': '700561',
#     'Desctiption': 'Screw10x 25 Din933- 8.8 Zp',
#     'Description': 'Screw10x 25 Din933- 8.8 Zp'},
#    {'Item Number': '701765',
#     'Desctiption': 'Washer Lock A  8,4  Din6798 Zp',
#     'Description': 'Washer Lock A  8,4  Din6798 Zp'},
#    {'Item Number': '704537',
#     'Desctiption': 'Nut Nyloc  8      Din985- 8 A3b',
#     'Description': 'Nut Nyloc  8      Din985- 8 A3b'},
#    {'Item Number': '468768',
#     'Desctiption': '0000-350-1000-a Benzinhahn B&s',
#     'Description': '0000-350-1000-a Benzinhahn B&s'},
#    {'Item Number': '705360',
#     'Desctiption': 'Screw 10x1,0 X 35 Din961-10.9 A3b',
#     'Description': 'Screw 10x1,0 X 35 Din961-10.9 A3b'},
#    {'Item Number': '47312030', 'Desctiption': 'Gear', 'Description': 'Gear'},
#    {'Item Number': '473115', 'Desctiption': '473115', 'Description': '473115'},
#    {'Item Number': '703813',
#     'Desctiption': 'Nut Nyloc 10      Din985-10 A3b',
#     'Description': 'Nut Nyloc 10      Din985-10 A3b'},
#    {'Item Number': '47317310', 'Desctiption': 'Disc', 'Description': 'Disc'},
#    {'Item Number': '706018',
#     'Desctiption': 'Nut Nyloc 10x1    Din985-10 A2k',
#     'Description': 'Nut Nyloc 10x1    Din985-10 A2k'},
#    {'Item Number': '464932',
# ...
#    {'Item Number': '514175',
#     'Desctiption': '6170-702-6910-a Bearing Bock Mower Drive',
#     'Description': '6170-702-6910-a Bearing Bock Mower Drive'},
#    {'Item Number': '476634',
#     'Desctiption': '9503-003-6841-b Bearing 6205 2rs (hch)',
#     'Description': '9503-003-6841-b Bearing 6205 2rs (hch)'},
#    {'Item Number': '458568',
#     'Desctiption': '9039-488-1839-a Shr M8x25 Din7500 Sperrz',
#     'Description': '9039-488-1839-a Shr M8x25 Din7500 Sperrz'},
#    {'Item Number': '468102', 'Desctiption': 'Driver', 'Description': 'Driver'},
#    {'Item Number': '468116', 'Desctiption': 'Pulley', 'Description': 'Pulley'},
#    {'Item Number': '46835530',
#     'Desctiption': '6170-702-0710-b Flange Cpl. Blade Shaft',
#     'Description': '6170-702-0710-b Flange Cpl. Blade Shaft'},
#    {'Item Number': '473402',
#     'Desctiption': '6165-760-1200-a Pulley 92',
#     'Description': '6165-760-1200-a Pulley 92'},
#    {'Item Number': '701082',
#     'Desctiption': 'Washer Fl Thi 10,5 Din7349 Zp',
#     'Description': 'Washer Fl Thi 10.5 Din7349 Zp'},
#    {'Item Number': '701508',
#     'Desctiption': 'Screw 10x70 Din933- 8.8 Zp',
#     'Description': 'Screw 10x70 Din933- 8.8 Zp'},
#    {'Item Number': '473209', 'Desctiption': '473209', 'Description': '473209'},
#    {'Item Number': '375953',
#     'Desctiption': 'Screw 8x 40 A3r 8.8',
#     'Description': 'Screw 8x 40 A3r 8.8'},
#    {'Item Number': '47330230',
#     'Desctiption': 'Tension Lever Mowing Belt A 102',
#     'Description': 'Tension Lever Mowing Belt A 102'},
#    {'Item Number': '52111030',
#     'Desctiption': 'Radbolzen 102 Verz',
#     'Description': 'Radbolzen 102 Verz'},
#    {'Item Number': '514887',
#     'Desctiption': 'Wheel 125 R9005',
#     'Description': 'Wheel 125 R9005'},
#    {'Item Number': '47314302',
#     'Desctiption': 'Mähdeck 102 Cm A Geschw R3000',
#     'Description': 'Mähdeck 102 Cm A Geschw R3000'},
#    {'Item Number': '705657', 'Desctiption': 'Washer', 'Description': 'Washer'},
#    {'Item Number': '706086',
#     'Desctiption': 'Bolt  6x 20     603- 8.8a2k',
#     'Description': 'Bolt 6x 20 603- 8.8a2k'},
#    {'Item Number': '473445',
#     'Desctiption': 'Belt Cover Left 102 Cm',
#     'Description': 'Belt Cover Left 102 Cm'},
#    {'Item Number': '706611',
#     'Desctiption': 'Pin Iso 8741- 6x45-st A2k',
#     'Description': 'Pin Iso 8741- 6x45-st A2k'},
#    {'Item Number': '47340301',
#     'Desctiption': '6165-706-8200-a Folding Hinge Emak Av R9',
#     'Description': '6165-706-8200-a Folding Hinge Emak Av R9'},
#    {'Item Number': '473515',
#     'Desctiption': '6165-706-9500-a Schlitzschra F Klapps',
#     'Description': '6165-706-9500-a Schlitzschra F Klapps'},
#    {'Item Number': '473415',
#     'Desctiption': '6165-703-5130-a Tension Spring',
#     'Description': '6165-703-5130-a Tension Spring'},
#    {'Item Number': '47358201',
#     'Desctiption': '6165-780-2050-a Belt Cover Cpl.',
#     'Description': '6165-780-2050-a Belt Cover Cpl.'},
#    {'Item Number': '473446',
#     'Desctiption': 'Belt Cover Right 102 Cm',
#     'Description': 'Belt Cover Right 102 Cm'},
#    {'Item Number': '700702',
#     'Desctiption': 'Screw 6x 25 Din933- 8.8 Zp',
#     'Description': 'Screw 6x 25 Din933- 8.8 Zp'},
#    {'Item Number': '473337',
#     'Desctiption': 'Blade Support Al-ko',
#     'Description': 'Blade Support Al-ko'},
#    {'Item Number': '521207',
#     'Desctiption': 'Blade Right 52cm',
#     'Description': 'Blade Right 52cm'},
#    {'Item Number': '521208',
#     'Desctiption': 'Blade Left',
#     'Description': 'Blade Left'},
#    {'Item Number': '468354',
#     'Desctiption': '6170-702-1700-a Distanzring',
#     'Description': '6170-702-1700-a Distanzring'},
#    {'Item Number': '468101', 'Desctiption': 'Washer', 'Description': 'Washer'},
#    {'Item Number': '468881',
#     'Desctiption': '6170-087-1800-a Dichtring  Ansaugluft',
#     'Description': '6170-087-1800-a Dichtring Ansaugluft'},
#    {'Item Number': '473423',
#     'Desctiption': 'Benzintank Traktor',
#     'Description': 'Benzintank Traktor'},
#    {'Item Number': '514818',
#     'Desctiption': 'Attachment Rubber',
#     'Description': 'Attachment Rubber'},
#    {'Item Number': '47344901',
#     'Desctiption': 'Batteriekasten R9005 A',
#     'Description': 'Batteriekasten R9005 A'},
#    {'Item Number': '476109',
#     'Desctiption': 'Tank Cap Cpl.',
#     'Description': 'Tank Cap Cpl.'},
#    {'Item Number': '468820',
#     'Desctiption': '0751-010-7236-a Cable Tie 12,5x1000lg',
#     'Description': '0751-010-7236-a Cable Tie 12.5x1000lg'},
#    {'Item Number': '451000',
#     'Desctiption': 'Battery Csb Gp 12v/17ah',
#     'Description': 'Battery Csb Gp 12v/17ah'},
#    {'Item Number': '47333330',
#     'Desctiption': 'Stützholm Lenkung A Verz',
#     'Description': 'Stützholm Lenkung A Green'},
#    {'Item Number': '514197',
#     'Desctiption': 'Ep Flange Sleeve',
#     'Description': 'Ep Flange Sleeve'},
#    {'Item Number': '705614',
#     'Desctiption': 'Shr 8x 40 Iso10642 - 8.8 A2k',
#     'Description': 'Shr 8x 40 Iso10642 - 8.8 A2k'},
#    {'Item Number': '473491',
#     'Desctiption': 'Gas Handle 2k Al-ko',
#     'Description': 'Gas Handle 2k Al-ko'},
#    {'Item Number': '700119',
#     'Desctiption': 'Nut Nyloc  5      Din985- 8 Zp',
#     'Description': 'Nut Nyloc 5 Din985- 8 Zp'},
#    {'Item Number': '701172',
#     'Desctiption': 'Setscrew 5x 12 Din933- 8.8 Zp',
#     'Description': 'Setscrew 5x 12 Din933- 8.8 Zp'},
#    {'Item Number': '543560', 'Desctiption': '543560', 'Description': '543560'},
#    {'Item Number': '701489',
#     'Desctiption': 'Setscrew 6x 35 Din933- 8.8 Zp',
#     'Description': 'Setscrew 6x 35 Din933- 8.8 Zp'},
#    {'Item Number': '473496',
#     'Desctiption': 'Bedienkonsolenblech A',
#     'Description': 'Bedienkonsolenblech A'},
#    {'Item Number': '468780',
#     'Desctiption': '6170-180-1130-a Remote Acceleration B&s',
#     'Description': '6170-180-1130-a Remote Acceleration B&amp;s'},
#    {'Item Number': '47333130',
#     'Desctiption': 'Shaft Steering',
#     'Description': 'Shaft Steering'},
#    {'Item Number': '473174', 'Desctiption': '473174', 'Description': '473174'},
#    {'Item Number': '51400930',
#     'Desctiption': 'Steering Sprocket',
#     'Description': 'Steering Sprocket'},
#    {'Item Number': '704275',
#     'Desctiption': 'Sti Span Iso8748-st 6x24',
#     'Description': 'Sti Span Iso8748-st 6x24'},
#    {'Item Number': '473384',
#     'Desctiption': 'Sitz Al-ko',
#     'Description': 'Sitz Al-ko'},
#    {'Item Number': '468231',
#     'Desctiption': '6170-430-0540-a Seat Switch T5',
#     'Description': '6170-430-0540-a Seat Switch T5'},
#    {'Item Number': '468890',
#     'Desctiption': '6170-706-0731-a Abdeckung Sitzschalter',
#     'Description': '6170-706-0731-a Abdeckung Seatschalter'},
#    {'Item Number': '468229',
#     'Desctiption': '6170-763-5440-a Halteblech Sitz',
#     'Description': '6170-763-5440-a Halteblech Sitz'},
#    {'Item Number': '47631930',
#     'Desctiption': 'Leaf Spring Seat Tractor',
#     'Description': 'Leaf Spring Seat Tractor'},
#    {'Item Number': '47600930',
#     'Desctiption': 'Metal Seat Switch Tractor',
#     'Description': 'Metal Seat Switch Tractor'},
#    {'Item Number': '702367',
#     'Desctiption': 'Bolt  8x 40 Din931- 8.8 Zp',
#     'Description': 'Bolt 8x 40 Din931- 8.8 Zp'},
#    {'Item Number': '47631830',
#     'Desctiption': 'Collar Screw Seat Tractor',
#     'Description': 'Collar Screw Seat Tractor'},
#    {'Item Number': '46834830',
#     'Desctiption': '6170-763-0710-a Distanzhülse Sitz Verz',
#     'Description': '6170-763-0710-a Distanzhülse Sitz Verz'},
#    {'Item Number': '46822830',
#     'Desctiption': '6170-703-1750-a Scharnierbolze Sitz Verz',
#     'Description': '6170-703-1750-a Scharnierbolze Sitz Verz'},
#    {'Item Number': '47331301',
#     'Desctiption': 'Verschiebeblech Comfort A R9005',
#     'Description': 'Verschiebeblech Comfort A R9005'},
#    {'Item Number': '468230',
#     'Desctiption': '6170-703-6405-a Seat Spring',
#     'Description': '6170-703-6405-a Seat Spring'},
#    {'Item Number': '468697',
#     'Desctiption': '9417-021-7530-a Schnellbefestig 10x27x7',
#     'Description': '9417-021-7530-a Schnellbefestig 10x27x7'},
#    {'Item Number': '46822701',
#     'Desctiption': '6170-763-6000-a Arretierblech Sitz R9005',
#     'Description': '6170-763-6000-a Arretierblech Sitz R9005'},
#    {'Item Number': '700507',
#     'Desctiption': 'Plate Feather 25x12,2x0,9',
#     'Description': 'Flat Feather 25x12.2x0.9'},
#    {'Item Number': '531820',
#     'Desctiption': 'Sl-retainer 10sxn08',
#     'Description': 'Sl-retainer 10sxn08'},
#    {'Item Number': '47331430',
#     'Desctiption': 'Distanzbuchse Sitz A Verz',
#     'Description': 'Distanzbuchse Sitz A Verz'},
#    {'Item Number': '514346',
#     'Desctiption': 'Cover Cap D-35 Ral9005',
#     'Description': 'Cover Cap D-35 Ral9005'},
#    {'Item Number': '52174130',
#     'Desctiption': 'Anschlagwinkel Fernbedienung Verz',
#     'Description': 'Anschlagwinkel Fernbedienung Verz'},
#    {'Item Number': '468783',
#     'Desctiption': '6170-180-2610-a Chockerzug Kawa 580',
#     'Description': '6170-180-2610-a Chockerzug Kawa 580'},
#    {'Item Number': '476623',
#     'Desctiption': 'Bottom Of Catcher + Fabric Tractor Solo',
#     'Description': 'Bottom Of Catcher + Fabric Tractor Solo'},
#    {'Item Number': '47356601',
#     'Desctiption': 'Empty Conduit Box A R9005',
#     'Description': 'Empty Conduit Box A R9005'},
#    {'Item Number': '473487',
#     'Desctiption': 'Reflektor Box Hinten Rechts',
#     'Description': 'Reflektor Box Hinten Rechts'},
#    {'Item Number': '473486',
#     'Desctiption': 'Reflector Catcher Behind Left',
#     'Description': 'Reflector Catcher Behind Left'},
#    {'Item Number': '47348102',
#     'Desctiption': 'Box Cap R3000',
#     'Description': 'Head Box R3000'},
#    {'Item Number': '47348501',
#     'Desctiption': 'Boxgriff R9005',
#     'Description': 'Boxgrip R9005'},
#    {'Item Number': '706607',
#     'Desctiption': 'Bolt 6x 20 7985- 4.8-torx A3r',
#     'Description': 'Bolt 6x 20 7985- 4.8-torx A3r'},
#    {'Item Number': '47326901',
#     'Desctiption': 'Box Upper Handle',
#     'Description': 'Box Upper Handle'},
#    {'Item Number': '47327301',
#     'Desctiption': 'Box Down Tube',
#     'Description': 'Box Down Tube'},
#    {'Item Number': '700137',
#     'Desctiption': 'Washer Fl A  6,4 Din125-st Zp',
#     'Description': 'Washer Fl A 6.4 Din125-st Zp'},
#    {'Item Number': '700705',
#     'Desctiption': 'Scr 6x 35 Din 603- 4.6gv',
#     'Description': 'Scr 6x 35 From 603- 4.6gv'},
#    {'Item Number': '47327601',
#     'Desctiption': 'Support Plate Catcher R9005',
#     'Description': 'Support Plate Catcher R9005'},
#    {'Item Number': '526135',
#     'Desctiption': 'Sfs-taptite 6x30    2019 Torx A3b',
#     'Description': 'Sfs-taptite 6x30 2019 Torx A3b'},
#    {'Item Number': '473567',
#     'Desctiption': 'Handle For Empty Conduit 2k A',
#     'Description': 'Handle For Empty Conduit 2k A'},
#    {'Item Number': '514174',
#     'Desctiption': 'Gear Change',
#     'Description': 'Gear Change'},
#    {'Item Number': '461630',
#     'Desctiption': 'Expander Mulch Insert',
#     'Description': 'Expander Mulch Insert'},
#    {'Item Number': '46162030',
#     'Desctiption': 'Halteöse M5 Verz',
#     'Description': 'Halteöse M5 Green'},
#    {'Item Number': '510566',
#     'Desctiption': 'Schnellbefestiger 8sxn26',
#     'Description': 'Schnellbefestiger 8sxn26'},
#    {'Item Number': '46162601',
#     'Desctiption': 'Holding Rod Mulching Wedge 105cm R9005',
#     'Description': 'Holding Rod Mulching Wedge 105cm R9005'},
#    {'Item Number': '46162701',
#     'Desctiption': 'Mulching Key R9005',
#     'Description': 'Mulching Key R9005'},
#    {'Item Number': '700240',
#     'Desctiption': 'Washer Fl A  5,3 Din125-st Zp',
#     'Description': 'Washer Fl A 5.3 Din125-st Zp'},
#    {'Item Number': '46162230',
#     'Desctiption': 'Bolzen Für Mulchkeil Verz',
#     'Description': 'Bolzen Für Mulchkeil Verz'},
#    {'Item Number': '461623',
#     'Desctiption': 'Haltefeder Für Mulchkeil',
#     'Description': 'Haltefeder Für Mulchkeil'},
#    {'Item Number': '514683',
#     'Desctiption': 'Schaltgehäuse   521339',
#     'Description': 'Switch housing 521339'},
#    {'Item Number': '468878',
#     'Desctiption': 'Shr Pt-kb 50x12 Wn1451 Znni8f',
#     'Description': 'Shr Pt-kb 50x12 Wn1451 Znni8f'},
#    {'Item Number': '468680',
#     'Desctiption': '6170-430-0520-a Pressure Switch 6700-50b',
#     'Description': '6170-430-0520-a Pressure Switch 6700-50b'},
#    {'Item Number': '473942',
#     'Desctiption': 'Electronic Module Backwards Al-ko',
#     'Description': 'Electronic Module Backwards Al-ko'},
#    {'Item Number': '473618',
#     'Desctiption': 'Cable Harness',
#     'Description': 'Cable Harness'},
#    {'Item Number': '473910',
#     'Desctiption': '6140-430-8800-a Fill Level Indicator',
#     'Description': '6140-430-8800-a Fill Level Indicator'},
#    {'Item Number': '468603',
#     'Desctiption': 'Ignition Switch',
#     'Description': 'Ignition Switch'},
#    {'Item Number': '473258',
#     'Desctiption': 'Ignition Key',
#     'Description': 'Ignition Key'},
#    {'Item Number': '473587',
#     'Desctiption': 'Drucktaster Rund A',
#     'Description': 'Drucktaster Rund A'},
#    {'Item Number': '473737',
#     'Desctiption': '6170-430-0570-a Switch Cutting Deck',
#     'Description': '6170-430-0570-a Switch Cutting Deck'},
#    {'Item Number': '47350201', 'Desctiption': 'Cover', 'Description': 'Cover'},
#    {'Item Number': '700106',
#     'Desctiption': 'Nut Pl  5        Din934- 8 Zp',
#     'Description': 'Nut Pl 5 Din934- 8 Zp'},
#    {'Item Number': '521819',
#     'Desctiption': 'Stecksicherung 15 A',
#     'Description': 'Stecksicherung 15 A'},
#    {'Item Number': '703106',
#     'Desctiption': 'Setscrew 5x 25 Din933- 8.8 Zp',
#     'Description': 'Setscrew 5x 25 Din933- 8.8 Zp'},
#    {'Item Number': '700126',
#     'Desctiption': 'Washer Spr B 5 Din127 Zp',
#     'Description': 'Washer Spr B 5 Din127 Zp'},
#    {'Item Number': '468678',
#     'Desctiption': '6170-437-0800-a Siche Hsb Fuse Rated 32v',
#     'Description': '6170-437-0800-a Siche Hsb Fuse Rated 32v'},
#    {'Item Number': '521849',
#     'Desctiption': 'Relais 12v - 20/30a',
#     'Description': 'Relay 12v - 20/30a'},
#    {'Item Number': '468981',
#     'Desctiption': '6160-405-8000-a Isolierplatte Startrel',
#     'Description': '6160-405-8000-a Isolierplatte Startrel'},
#    {'Item Number': '521361',
#     'Desctiption': 'Starter Relays 12v/200a',
#     'Description': 'Starter Relays 12v/200a'},
#    {'Item Number': '521375',
#     'Desctiption': 'Hexagon Nut + Tooth Lock 1/4"-20 Un  8.8',
#     'Description': 'Hexagon Nut + Tooth Lock 1/4&quot;-20 Un 8.8'},
#    {'Item Number': '493082',
#     'Desctiption': 'Led Lampe',
#     'Description': 'Led Lamps'},
#    {'Item Number': '476712',
#     'Desctiption': '6005-435-0410-a Limit Switch No Ip67',
#     'Description': '6005-435-0410-a Limit Switch No Ip67'},
#    {'Item Number': '476713',
#     'Desctiption': '6001-430-0210-a Limit Switch Nc Ip67',
#     'Description': '6001-430-0210-a Limit Switch Nc Ip67'},
#    {'Item Number': '526521',
#     'Desctiption': 'Quick Fastening 3sxn26',
#     'Description': 'Quick Fastening 3sxn26'},
#    {'Item Number': '521363',
#     'Desctiption': 'Kabel Rot Starter/relais',
#     'Description': 'Kabel Rot Starter/relay'},
#    {'Item Number': '473620',
#     'Desctiption': 'Kabel Hauptsicherung Starterr Ha',
#     'Description': 'Kabel Hauptsicherung Starterr Ha'},
#    {'Item Number': '473619',
#     'Desctiption': 'Kabel Hauptsicherung Batterie Ha',
#     'Description': 'Kabel Hauptsicherung Batterie Ha'},
#    {'Item Number': '701352',
#     'Desctiption': 'Nut Nyloc  4      Din985- 8 Zp',
#     'Description': 'Nut Nyloc 4 Din985- 8 Zp'},
#    {'Item Number': '706096',
#     'Desctiption': 'Setscrew 4x 12 Iso10642 - 8.8 A2k',
#     'Description': 'Setscrew 4x 12 Iso10642 - 8.8 A2k'},
#    {'Item Number': '473661',
#     'Desctiption': '6170-440-0500-a Adapter Emak',
#     'Description': '6170-440-0500-a Adapter Emak'},
#    {'Item Number': '493511',
#     'Desctiption': 'Fill Level Indicator Cpl.',
#     'Description': 'Fill Level Indicator Cpl.'},
#    ...],
#   'Img Url': 'https://alko-garden.ro/out/media/exploded_views/2021/9/2021-09-127621-10.gif',
#   'Img Filename': 'SGL0000015814-Tractor lawn mower T22-105.1 HD-A V2 SOLO.jpg'}]
